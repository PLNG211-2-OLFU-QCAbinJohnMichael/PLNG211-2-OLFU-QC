# %% [markdown]
# Introduction to Phyton

# %% [markdown]
# Phyton Variables

# %%
x = "Michael"
a,b,c = 1,2,3
print (a)
print (b)
print (c)
print (x)
# Out:
# 1
# 2
# 3
# Michael

# %% [markdown]
# Casting

# %%
c="michael" #This is a type of string
print(c)
b = float(4)
print (b)
# Out:
# michael
# 4.0

# %% [markdown]
# Type Function

# %%
x = 5
y = "michael"
print (type (x))
print (type (y))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# Double Quotes or Single Quotes

# %%
x= "michael"
y= 'john'
print (x)
print (y)
# Out:
# michael
# john

# %% [markdown]
# Case Sensitive

# %%
A = 1
a = 2
print (A)
print (a)
# Out:
# 1
# 2

# %% [markdown]
# Multiple Variables

# %%
a,b,c = 2,3,4
print (a)
print (b)
print (c)
# Out:
# 2
# 3
# 4

# %% [markdown]
# One to Multiple Variables

# %%
a=b=c = "Multiple"
print (a)
print (b)
print (c)
# Out:
# Multiple
# Multiple
# Multiple

# %% [markdown]
# Output Variables

# %%
x = "a school"
y = "Our Lady of Fatima is "

print (y + "a school")
print (y +x)
# Out:
# Our Lady of Fatima is a school
# Our Lady of Fatima is a school

# %% [markdown]
# Arithemetic

# %%
x = 5
y = 6
z = 7

print (x+ y)
print (y-x)
print (z*x)
# Out:
# 11
# 1
# 35

# %% [markdown]
# Assignment Operators

# %%
x= 5
x+=3
print (x)
print (x/4)
print (x%4)
# Out:
# 8
# 2.0
# 0

# %% [markdown]
# Comparison Operators

# %%
x = 6
y = 7
z = 1
print (x == (y-z))
print (z>x)
print (y>x)
# Out:
# True
# False
# True

# %% [markdown]
# Logical Operators

# %%
a,b,c,d = 2,3,2,3
print (b==d and a==c)
print (a>d or c<b)
# Out:
# True
# True

# %% [markdown]
# Identity Operators

# %%
a,b,c,d = 2,3,2,3

print (a is c)
print (d is c)
# Out:
# True
# False

# %% [markdown]
# Bitwise Operators

# %%
print (4 << 2)
print (4 >> 2)
# Out:
# 16
# 1
